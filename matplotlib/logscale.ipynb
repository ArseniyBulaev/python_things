# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_subplot()
x = np.arange(-10*np.pi, 10*np.pi, 0.1)
y = np.sin(x) / x * np.exp(-np.abs(x/10))
ax.grid()
#ax.semilogy(x, y)
#ax.plot(x,y)
#ax.set_yscale('log', base=10, subs=[2,9])
#ax.set_yscale('symlog', linthresh=2)
ax.loglog(x,y)
